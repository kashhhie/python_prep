# %%
#list
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[10,20,30,"hello",10.5]
print(l)
print(type(l))
print(l[0])   #indexed
l[0]=1000
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5]
# <class 'list'>
# 10
# [1000, 20, 30, 'hello', 10.5]

# %%
#indexing and slicing
l=[10,20,30,"hello",10.5,1000,200,300,100]
print(l[3])
print(l[3][1])
print(l[-3])
print(l[-3])
print(l[::-1])
# Out:
# hello
# e
# 200
# 200
# [100, 300, 200, 1000, 10.5, 'hello', 30, 20, 10]

# %%
l=[10,20,30,"hello",1000,10.5,11]
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# hello
# 1000
# 10.5
# 11

# %%
#function
#len()
#max()
#min()
l=[10,20,30,"hello",10.5,1000,11]
print(len(l))
count=0
for i in l:
    count=count+1
print(count)
# Out:
# 7
# 7

# %%
#indirect iteration

# %%
#methods
#add element to an existing list
#append
#listobj.append(value/obj)
#append method add new element at the last position... -1
l=[10,20,30,"hello",10.5]
l.append(1000)
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 1000]

# %%
l=[10,20,30,"hello",0.5]
l.append([100,200,300])
print(l)
# Out:
# [10, 20, 30, 'hello', 0.5, [100, 200, 300]]

# %%
l=[100,23,24,11,17,32,35,98,12,7]
l1=[]
for i in l:
    if i%2==0:
        l1.append(i)
print(l1)
# Out:
# [100, 24, 32, 98, 12]

# %%
l=[]
for i in range(0,8,2):
    l.append(chr(65+i))
print(l)
# Out:
# ['A', 'C', 'E', 'G']
